# %%
from holoviews.examples.reference.streams.bokeh.Selection1D_tap import average
from networkx.algorithms.structuralholes import mutual_weight

print("我是东东哇！")

# %%
print("ich bin guowendong")

# %%
#哈哈哈哈哈
#你觉得怎么样！
#对不对
print("wie finden sie?")
#你是不是觉得我很强，其实不是这样，每个人都有自己的难处。
#你不信，我们也没有办法呀
print("没人要别急躁，东西南北找学校看广告查资料，就到渭南莆田学院去深造！")
#毕竟每个人都是一个独立大的个体谁说还不是呢？

# %%
cars = 100
space_in_a_car = 4
drivers = 30
passengers = 90
cars_not_driven = cars - drivers
cars_driven = drivers
carpool_capacity = cars_driven * space_in_a_car
average_passenger_passengers = passengers / cars_driven

print("这里有",cars,"辆小汽车")
print("这里只有",drivers,"位司机")
print("There are this day have",cars_not_driven,"Auto nicht fahrer")
print("我们今天可以运送",carpool_capacity,"名乘客。")
print("我们这里今天总共有",passengers,"位乘客")
print("我们需要在每辆车中安排",average_passenger_passengers,"位乘客")

# %%
my_name = "郭文东"
my_alter = 35 #是不是已经没有救了
mein_height = 76 #这里单位是英寸
my_weight = 60 #这里计量单位是磅
my_eyes = "black"
my_teeth = '白色'
my_hair = "rot"
print(f"让我们来谈谈{my_alter}。")
total = my_alter + mein_height + my_weight
print(f"如果我把{my_alter}、{mein_height}和{my_weight}加起来，我会得到{total}")

# %%
print("玛丽有一只小羊羔。")
print("它的羊毛白的像{}。".format('雪'))
print("无论马力走哪里，小羊羔都会跟着。")
print("." * 10) #这个效果会怎么样的？
end1 = "奶"
end2 = "酪"
end3 = "三"
end4 = "明"
end5 = "治"
end6 = "的"
end7 = "汉"
end8 = "堡"
end9 = "包"
end10 = "真"
end11 = "好"
end12 = "吃"

#注意后面的逗号，试着把它去掉，看看会发什么？
print(end1 + end2 + end3 + end4 + end5 + end6,end='')
print(end7 + end8 + end9 + end10 + end11 + end12)

# %%
tabby_cat = "\t我被缩进了。"
persian_cat = "我被拆分\n成两行了。"
backslash = "我是\\一只\\小猫。"

fat_cat = """
我给你列一个清单：
\t*猫粮
\t*小鱼干
\t*猫咪薄荷糖\n\t*草本植物
"""
print(tabby_cat)
print(persian_cat)
print(backslash)
print(fat_cat)

# %%
print("你多大了？",end=' ')
age = input()
print("你的身高是多少呀？",end=' ')
height = input()
print("你的体重是多少？",end=' ')
weight = input()

print(f"所以，你{age}岁,身高{height},体重{weight}。")

# %%
print("请输入你的名字：")
name = input()
print("你好",name)

print("你最喜欢的水果是什么？")
fruit = input()
print("我最喜欢的水果是",fruit)

# %%
name = input("请输入你的名字！")
print("Hallo，"+name)

# %%
age = input("您的年龄是多少：")
print(age)
Education_bachground = input("你是什么学历:")
print(Education_bachground)
Marital_status = input("您的婚姻状况是：")
print(Marital_status)
print(f"所以您的年龄是{age},您的婚姻状况是{Marital_status},您的教育状态{Education_bachground}")
